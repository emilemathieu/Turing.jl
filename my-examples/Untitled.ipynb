# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns
# Out:
# /usr/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = [[[0.0635594, 0.0630262, 0.0636666, 0.0696762, 0.0640119, 0.0621704, 0.0644749, 0.0648439, 0.0639546, 0.0640314], 
        [0.432333, 0.176058, 0.151113, 0.179531, 0.157556, 0.145854, 0.159622, 0.166765, 0.17628, 0.182787],
        [0.184334, 0.0967182, 0.130805, 0.362402, 0.310646, 0.19718, 0.314875, 0.345291, 0.27502, 0.190921],
        [1.90004, 1.63576, 1.73519, 1.95505, 1.54601, 2.27457, 1.91868, 1.21054, 0.821816, 1.87129],
        [4.23444, 4.52288, 3.11278, 4.45471, 3.6981, 2.66473, 2.31119, 2.47676, 2.81752, 4.69742],
        [22.835, 24.1264, 8.8443, 23.9132, 32.9697, 29.7607, 6.48231, 32.0796, 22.2456, 24.7406],
        [42.3697, 55.8415, 60.7341, 44.2337, 46.9909, 44.7266, 16.8224, 40.294, 61.0135, 52.4543]],
        [[0.0682389, 0.0643634, 0.0722541, 0.0871364, 0.0808385, 0.0759451, 0.0686679, 0.0683381, 0.0656029, 0.0654895],
         [0.476783, 0.126666, 0.165148, 0.10796, 0.116201, 0.0882551, 0.148423, 0.139673, 0.127275, 0.123726],
         [0.275421, 0.190583, 0.266579, 0.267253, 0.219276, 0.248705, 0.20545, 0.254472, 0.220632, 0.247225],
         [1.54415, 1.21878, 0.730731, 1.52479, 1.40159, 1.35333, 1.1901, 1.28128, 1.15211, 1.40717],
         [2.61413, 2.2476, 2.93662, 2.64873, 2.35507, 2.03732, 2.16246, 1.94227, 2.89428, 2.97252],
         [24.0018, 14.6833, 18.1906, 20.6425, 24.2644, 14.1926, 22.3477, 16.9154, 11.308, 15.6575],
         [31.2196, 47.2304, 33.5858, 32.0571, 28.381, 34.9255, 39.1795, 39.1825, 26.0725, 42.922]]]

# %%
sns.tsplot(np.log(np.transpose(data[0])))
sns.tsplot(np.log(np.transpose(data[1])), color='red')

# %%
infiniteMixtureStick = 'stick'
infiniteMixtureLazy = 'lazy'
data=[(1,1,infiniteMixtureStick,0.068486),(1,2,infiniteMixtureStick,0.0746589),(1,3,infiniteMixtureStick,0.0685185),(1,4,infiniteMixtureStick,0.0670117),(1,5,infiniteMixtureStick,0.0662935),(1,6,infiniteMixtureStick,0.0670506),(1,7,infiniteMixtureStick,0.0713189),(1,8,infiniteMixtureStick,0.0694089),(1,9,infiniteMixtureStick,0.071057),(1,10,infiniteMixtureStick,0.0731168),(2,1,infiniteMixtureStick,0.499553),(2,2,infiniteMixtureStick,0.181594),(2,3,infiniteMixtureStick,0.157883),(2,4,infiniteMixtureStick,0.182981),(2,5,infiniteMixtureStick,0.178544),(2,6,infiniteMixtureStick,0.15589),(2,7,infiniteMixtureStick,0.180119),
y,0.180002),(2,3,infiniteMixtureLazy,0.224406),(2,4,infiniteMixtureLazy,0.23651),(2,5,infiniteMixtureLazy,0.19374),(2,6,infiniteMixtureLazy,0.162845),(2,7,infiniteMixtureLazy,0.235592),(2,8,infiniteMixtureLazy,0.224429),(2,9,infiniteMixtureLazy,0.217702),(2,10,infiniteMixtureLazy,0.23582),(3,1,infiniteMixtureLazy,0.525627),(3,2,infiniteMixtureLazy,0.412263),(3,3,infiniteMixtureLazy,0.435346),(3,4,infiniteMixtureLazy,0.448571),(3,5,infiniteMixtureLazy,0.503656),(3,6,infiniteMixtureLazy,0.421117),(3,7,infiniteMixtureLazy,0.7503),(3,8,infiniteMixtureLazy,0.483311),(3,9,infiniteMixtureLazy,0.36231),(3,10,infiniteMixtureLazy,0.396146),(4,1,infiniteMixtureLazy,3.47863),(4,2,infiniteMixtureLazy,2.72273),(4,3,infiniteMixtureLazy,4.42288),(4,4,infiniteMixtureLazy,3.44734),(4,5,infiniteMixtureLazy,3.17284),(4,6,infiniteMixtureLazy,3.22073),(4,7,infiniteMixtureLazy,4.1144),(4,8,infiniteMixtureLazy,2.26717),(4,9,infiniteMixtureLazy,3.88249),(4,10,infiniteMixtureLazy,2.56836),(5,1,infiniteMixtureLazy,8.334),(5,2,infiniteMixtureLazy,7.90186),(5,3,infiniteMixtureLazy,7.80178),(5,4,infiniteMixtureLazy,10.8814),(5,5,infiniteMixtureLazy,10.11),(5,6,infiniteMixtureLazy,7.66703),(5,7,infiniteMixtureLazy,10.234),(5,8,infiniteMixtureLazy,7.0709),(5,9,infiniteMixtureLazy,8.37549),(5,10,infiniteMixtureLazy,9.6217),(6,1,infiniteMixtureLazy,57.4929),(6,2,infiniteMixtureLazy,57.3902),(6,3,infiniteMixtureLazy,61.805),(6,4,infiniteMixtureLazy,54.867),(6,5,infiniteMixtureLazy,46.4569),(6,6,infiniteMixtureLazy,56.2867),(6,7,infiniteMixtureLazy,48.9635),(6,8,infiniteMixtureLazy,83.3679),(6,9,infiniteMixtureLazy,56.8016),(6,10,infiniteMixtureLazy,65.1702),(7,1,infiniteMixtureLazy,107.17),(7,2,infiniteMixtureLazy,148.816),(7,3,infiniteMixtureLazy,148.479),(7,4,infiniteMixtureLazy,127.725),(7,5,infiniteMixtureLazy,156.051),(7,6,infiniteMixtureLazy,118.059),(7,7,infiniteMixtureLazy,161.291),(7,8,infiniteMixtureLazy,214.573),(7,9,infiniteMixtureLazy,108.92),(7,10,infiniteMixtureLazy,112.188)]

# %%
df = pd.DataFrame(data)

# %%
df.columns = ['n_particles', 'rerun', 'method', 'time']

# %%
df['time'] = np.log(df['time'])

# %%
sns.pointplot(data=df, x='n_particles', y='time', hue='method')
